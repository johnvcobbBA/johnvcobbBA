# %% [markdown]
# # 'Likes' Report
# #### John Cobb
# #### September 15, 2023
# For my hypothesis, I believe that user 'cacandassociates' has the most media interaction in the set of data that was collected. The theorectical and statistical applications of this result could include potential marketing to this certain group, if they have the most likes. It could also mean if you looking for a partner to market with, they are loyal to your page.
# Data included in the liked posed json file is essential for testing this hypothesis as it contains the actual materials I need to declare the hypothesis true or not. Without the file I would just be making a bold claim with no evidence to back it up.

# %% [markdown]
# Although this is not my data it had to have come from somewhere. First of all, This is Dr. Silva's personal data, but it comes from instagram who collects data in order to help its users promote and reach a target audience. It's important for learning the demographics of the followers and users who like a certain page. It encourages businesses and brands to use instagram while providing insights that could help them excel on the platform. This data is reliable in that it shows exactly which users interact with a page, how often they interact, and even the timing of which people use instagram. The data in unreliable in that it only shows instagram user data. it is exclusive to users of the platform so you only real idea you have comes from a small online group.

# %%
import pandas as pd
import json
with open("/Users/johncobb/Downloads/technogecko_20200714_toshare/likes.json") as ig:
    insta_data = json.load(ig)

# %%
insta_data
# Out:
# {'media_likes': [['2020-07-11T04:39:28+00:00', 'ball_doesnt_lie'],
#   ['2020-07-11T04:39:05+00:00', 'ball_doesnt_lie'],
#   ['2020-07-05T17:25:44+00:00', 'ali_saurusrex'],
#   ['2020-07-03T03:40:02+00:00', 'cacandassociates'],
#   ['2020-06-25T17:41:50+00:00', 'cacandassociates'],
#   ['2020-06-22T23:01:55+00:00', 'reams_esq'],
#   ['2020-06-08T15:05:46+00:00', 'emmyr0o'],
#   ['2020-06-07T12:46:29+00:00', 'ali_saurusrex'],
#   ['2020-06-02T01:03:28+00:00', 'colin_storm'],
#   ['2020-05-25T16:38:14+00:00', 'ali_saurusrex'],
#   ['2020-05-19T23:38:40+00:00', 'colin_storm'],
#   ['2020-05-18T13:42:30+00:00', 'emmyr0o'],
#   ['2020-05-14T13:51:03+00:00', 'emmyr0o'],
#   ['2020-05-12T21:31:12+00:00', 'cacandassociates'],
#   ['2020-05-11T05:07:31+00:00', 'inalull'],
#   ['2020-05-07T18:07:52+00:00', 'reams_esq'],
#   ['2020-05-06T00:33:58+00:00', 'inalull'],
#   ['2020-04-30T19:54:48+00:00', 'emmyr0o'],
#   ['2020-04-28T12:58:14+00:00', 'inalull'],
# ...

# %%
insta_data["media_likes"]
# Out:
# [['2020-07-11T04:39:28+00:00', 'ball_doesnt_lie'],
#  ['2020-07-11T04:39:05+00:00', 'ball_doesnt_lie'],
#  ['2020-07-05T17:25:44+00:00', 'ali_saurusrex'],
#  ['2020-07-03T03:40:02+00:00', 'cacandassociates'],
#  ['2020-06-25T17:41:50+00:00', 'cacandassociates'],
#  ['2020-06-22T23:01:55+00:00', 'reams_esq'],
#  ['2020-06-08T15:05:46+00:00', 'emmyr0o'],
#  ['2020-06-07T12:46:29+00:00', 'ali_saurusrex'],
#  ['2020-06-02T01:03:28+00:00', 'colin_storm'],
#  ['2020-05-25T16:38:14+00:00', 'ali_saurusrex'],
#  ['2020-05-19T23:38:40+00:00', 'colin_storm'],
#  ['2020-05-18T13:42:30+00:00', 'emmyr0o'],
#  ['2020-05-14T13:51:03+00:00', 'emmyr0o'],
#  ['2020-05-12T21:31:12+00:00', 'cacandassociates'],
#  ['2020-05-11T05:07:31+00:00', 'inalull'],
#  ['2020-05-07T18:07:52+00:00', 'reams_esq'],
#  ['2020-05-06T00:33:58+00:00', 'inalull'],
#  ['2020-04-30T19:54:48+00:00', 'emmyr0o'],
#  ['2020-04-28T12:58:14+00:00', 'inalull'],
#  ['2020-04-28T03:28:35+00:00', 'cacandassociates'],
# ...

# %%
likes_data = pd.DataFrame(insta_data["media_likes"])

# %%
likes_data
# Out:
#                              0                 1
# 0    2020-07-11T04:39:28+00:00   ball_doesnt_lie
# 1    2020-07-11T04:39:05+00:00   ball_doesnt_lie
# 2    2020-07-05T17:25:44+00:00     ali_saurusrex
# 3    2020-07-03T03:40:02+00:00  cacandassociates
# 4    2020-06-25T17:41:50+00:00  cacandassociates
# ..                         ...               ...
# 330  2013-02-05T02:58:46+00:00            natgeo
# 331  2013-02-05T02:22:24+00:00       aroseroar16
# 332  2013-02-05T01:29:31+00:00       aroseroar16
# 333  2013-02-04T17:42:04+00:00     ali_saurusrex
# 334  2013-02-04T17:39:15+00:00      a_matt_silva
#
# [335 rows x 2 columns]

# %%
 likes_data[1]
# Out:
# 0       ball_doesnt_lie
# 1       ball_doesnt_lie
# 2         ali_saurusrex
# 3      cacandassociates
# 4      cacandassociates
#              ...
# 330              natgeo
# 331         aroseroar16
# 332         aroseroar16
# 333       ali_saurusrex
# 334        a_matt_silva
# Name: 1, Length: 335, dtype: object

# %%
likes_data.columns
# Out:
# Index([0, 1], dtype='int64')

# %%
df = likes_data.rename({0:'Timestamp',1: 'User'}, axis = 'columns')

# %%
df
# Out:
#                      Timestamp              User
# 0    2020-07-11T04:39:28+00:00   ball_doesnt_lie
# 1    2020-07-11T04:39:05+00:00   ball_doesnt_lie
# 2    2020-07-05T17:25:44+00:00     ali_saurusrex
# 3    2020-07-03T03:40:02+00:00  cacandassociates
# 4    2020-06-25T17:41:50+00:00  cacandassociates
# ..                         ...               ...
# 330  2013-02-05T02:58:46+00:00            natgeo
# 331  2013-02-05T02:22:24+00:00       aroseroar16
# 332  2013-02-05T01:29:31+00:00       aroseroar16
# 333  2013-02-04T17:42:04+00:00     ali_saurusrex
# 334  2013-02-04T17:39:15+00:00      a_matt_silva
#
# [335 rows x 2 columns]

# %%
df.groupby(['User']).count()
# Out:
#                              Timestamp
# User
# a_matt_silva                        18
# ali_saurusrex                       68
# andrewtcurry                         1
# aroseroar16                         29
# athenalemon                          1
# ball_doesnt_lie                      2
# bianchi_usa                          2
# bsnder                               5
# cacandassociates                    15
# camecol501                           2
# carswithoutlimits                    1
# catsandkilos                         1
# cbarker13                            9
# colin_storm                         11
# danneabreanne                       13
# drchadlarson                        10
# emmyr0o                             16
# favoritedekruyfonthecitadel          4
# holly.berry_22                       1
# ibiscycles                           1
# inalull                             10
# jackie.cc                            9
# jennjohnn                            3
# ...

# %% [markdown]
# Based on the results of the analysis, there is clear evidence to disprove my hypothesis. Although cacandassociates had a high number of likes,  ali_saurusrex had significantly more likes with 68. Although when looking at likes my hypothesis fails, but comments as well as story activites could end up revealing that cacandassociates has the most interactions. The data that was analyzed is limited in what it can reveal as it only contains two columns of information. Going forward the data could be further seperated to specifically look at certain days a users likes. Or furthermore, other files could be explored or combined to reveal more than what can be seen from the data above.
